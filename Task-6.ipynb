# %% [markdown]
# # Prediction Using Decision Tree Algorithm
#
# ### Task: 3
#
# ## Author: Simsima Gafoor

# %% [markdown]
# ##  Advantages of Using Decision Trees
# ##### Decision trees are simple to understand, interpret, and visualize
# ##### They can effectively handle both numerical and categorical data
# ##### They can determine the worst, best, and expected values for several scenarios
# ##### Decision trees require little data preparation and data normalization
# ##### They perform well, even if the actual model violates the assumptions

# %% [markdown]
# ###### Importing libraries in Python

# %%
import sklearn.datasets as datasets
import pandas as pd

# %% [markdown]
# ##### read the dataset

# %%
data=pd.read_csv("Iris7.csv")

# %% [markdown]
# data

# %% [markdown]
# ###### Forming the iris dataframe

# %% [markdown]
# ##### creating dataframe for the dataset

# %%
df=pd.DataFrame(data.iloc[:,[1,2,3,4]])

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
y=data.iloc[:,5]
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# # Defining the decision tree algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Let us visualize the Decision Tree to understand it better.

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25,10))
a = plot_tree(dtree, 
              feature_names=data.columns, 
              filled=True, 
              rounded=True, 
              fontsize=14)

# %% [markdown]
# ##### The first top node is the root node, if the condition is true then it's gini value will be 0
# ##### Then only one sample set will be there for gini equals zero and if the condition is false, gini equals 0.5 and 2 set of samples are there
# ##### This process is continuing untill it gets accurate sample set of values
# ##### Nodes below the root node are sub nodes and last nodes are called leaf node
# ##### Accurate value will be on the leaf nodes
